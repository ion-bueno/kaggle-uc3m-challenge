# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
train_comp = pd.read_csv('raw_data/train_set.csv')
test_comp = pd.read_csv('raw_data/test_set.csv')

X_train = pd.read_csv('preprocessed/X_train_median.csv', index_col=0)
y_train = pd.read_csv('preprocessed/y_train_median.csv', index_col=0)

# %%
X_train.head(5)
# Out:
#      feat_0    feat_1    feat_2    feat_3    feat_4    feat_5    feat_6  \
# 0 -1.238734 -1.803985  0.538156 -0.021383 -0.764698  2.531038 -2.911163
# 1 -0.276779  0.816044 -0.185421 -0.071902  0.398357  1.604708  8.392133
# 2 -0.016840  0.084576 -0.054180 -0.016868 -0.555238  5.770455  5.313584
# 3 -0.549744 -0.627953 -0.015312  0.004044  0.177872 -4.505224  2.374667
# 4 -3.778334 -0.467348 -0.054719 -0.190123  0.249530 -4.383149 -4.744214
#
#      feat_7    feat_8    feat_9  ...   feat_25   feat_26   feat_27   feat_28  \
# 0 -0.068284  0.385163  0.155206  ...  1.435644 -0.395159 -0.382656  0.458079
# 1  1.059966  1.100670 -0.012519  ... -0.955994 -0.025247  0.148199  0.332326
# 2  0.418525 -0.027305  0.181047  ... -0.138599  0.307675  0.042028  0.541914
# 3  1.352051 -0.086229 -0.122918  ... -0.955994 -0.025247 -0.092455 -1.655759
# 4 -1.053355  0.166302 -0.128143  ...  0.981535 -1.588127 -0.028753 -1.110832
#
#     feat_29   feat_30   feat_31   feat_32   feat_33   feat_34
# ...

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(X_train.corr(), fignum=f.number)
plt.xticks(range(X_train.select_dtypes(['number']).shape[1]), X_train.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(X_train.select_dtypes(['number']).shape[1]), X_train.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
cols = [0,1,3,13,14,15,21,29]

# %%
for i in X_train:
    plt.boxplot(X_train[i])
    plt.title(i)
    plt.show()

# %%
for i in X_train:
    plt.hist(X_train[i], bins=20)
    plt.title(i)
    plt.show()

# %%
for i in train_comp.iloc[:,2:]:
    plt.hist(train_comp[i].dropna(), bins=20)
    plt.title(i)
    plt.show()
